# %% [markdown]
# <a href="https://colab.research.google.com/github/adilmomin288-hub/aiml/blob/main/Count_Vowels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = input("Enter a string: ")

count = 0

for char in text:
    if char in "aeiouAEIOU":
        count += 1

print("Total vowels:", count)
# Out:
# Enter a string: 4
# Total vowels: 0
