# %% [markdown]
# <a href="https://colab.research.google.com/github/adilmomin288-hub/aiml/blob/main/Lists_to_Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
keys = ["name", "age", "city"]
values = ["Adil", 20, "Pune"]

data = dict(zip(keys, values))

print(data)
# Out:
# {'name': 'Adil', 'age': 20, 'city': 'Pune'}
