# %% [markdown]
# <a href="https://colab.research.google.com/github/adilmomin288-hub/aiml/blob/main/OOPS_Concept.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# what is oops .Explain Difference between class and object
# ans : 1)OOPS = Object Oriented Programming System.
# 2)It is used to organize code using:class/object
# Difference Between Class and Object:
# | Class               | Object     |
# | ------------------- | ---------- |
# | Blueprint           | Real thing |
# | Template            | Instance   |
# | Logical             | Physical   |
# | Example: Car design | Actual car |
